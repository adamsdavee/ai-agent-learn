# %%
from typing import Dict, TypedDict
from langgraph.graph import StateGraph
# Out:
# c:\Users\user\Documents\Codes\Python\learn_agent\.venv\Lib\site-packages\langchain_core\_api\deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
class AgentState(TypedDict):
    values: list[int]
    name: str
    result: str

# %%
def process_values(state: AgentState) -> AgentState:
    """"This function handles multiple different inputs"""

    print(state)

    state['result'] = f"Hi there {state['name']}! Your sum = {sum(state['values'])}"

    return state

# %%
graph = StateGraph(AgentState)

graph.add_node("processor", process_values)
graph.set_entry_point("processor")
graph.set_finish_point("processor")

app = graph.compile()

# %%
answers = app.invoke({"values": [1, 2, 3, 4], "name": "David"})

# print(answers)

print(answers['result'])
# Out:
# {'values': [1, 2, 3, 4], 'name': 'David', 'result': 'Hi there David! Your sum = 10'}
# Hi there David! Your sum = 10
